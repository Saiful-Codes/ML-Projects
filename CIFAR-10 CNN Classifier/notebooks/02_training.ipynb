# %% [markdown]
# # CIFAR-10 Classifier with CNN

# %% [markdown]
# ### Imports & Setup

# %%
import random
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split, Subset

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
import os, json

RESULTS_DIR = "results"
MODELS_DIR = "models"
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(MODELS_DIR, exist_ok=True)

# %% [markdown]
# ### Dataset and Dataloader Setup

# %%
MEAN = (0.4914, 0.4822, 0.4465)
STD  = (0.2023, 0.1994, 0.2010)

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

full_train_aug = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform_train
)

full_train_clean = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform_test
)

train_size = int(0.9 * len(full_train_aug))
val_size = len(full_train_aug) - train_size
train_split, val_split = random_split(full_train_aug, [train_size, val_size])

train_ds = Subset(full_train_aug, train_split.indices)
val_ds   = Subset(full_train_clean, val_split.indices)

test_ds = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=True, transform=transform_test
)

class_names = [
    "airplane","automobile","bird","cat","deer",
    "dog","frog","horse","ship","truck"
]
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def make_loaders(batch_size: int):
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
    test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)
    return train_loader, val_loader, test_loader

# %% [markdown]
# ### CNN Model

# %%
class SimpleCNN(nn.Module):
    def __init__(self, dropout: float = 0.2):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1   = nn.BatchNorm2d(32)

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2   = nn.BatchNorm2d(64)

        self.pool  = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1   = nn.Linear(64 * 8 * 8, 256)
        self.drop  = nn.Dropout(dropout)
        self.fc2   = nn.Linear(256, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.bn1(self.conv1(x))))
        x = self.pool(torch.relu(self.bn2(self.conv2(x))))

        x = x.view(x.size(0), -1)

        x = torch.relu(self.fc1(x))
        x = self.drop(x)
        x = self.fc2(x)
        
        return x

# %% [markdown]
# ### Training Utilities

# %% [markdown]
# **Training & Validation One Epoch**

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad(set_to_none=True)
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total


@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * images.size(0)
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total

# %% [markdown]
# **Training Multiple Epochs & Tracking**

# %%
def fit(model, train_loader, val_loader, criterion, optimizer, device, epochs: int):
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []

    best_val_acc = -1.0
    best_state = None

    for epoch in range(epochs):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
        va_loss, va_acc = evaluate(model, val_loader, criterion, device)

        train_losses.append(tr_loss)
        val_losses.append(va_loss)
        train_accs.append(tr_acc)
        val_accs.append(va_acc)

        if va_acc > best_val_acc:
            best_val_acc = va_acc
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

        print(
            f"Epoch {epoch+1}/{epochs} | "
            f"Train Loss: {tr_loss:.4f}, Train Acc: {tr_acc:.4f} | "
            f"Val Loss: {va_loss:.4f}, Val Acc: {va_acc:.4f}"
        )

    return {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "train_accs": train_accs,
        "val_accs": val_accs,
        "best_val_acc": best_val_acc,
        "best_state": best_state
    }

# %% [markdown]
# **Plotting Training Curves**

# %%
def plot_curves(history):
    plt.figure()
    plt.plot(history["train_losses"], label="Train Loss")
    plt.plot(history["val_losses"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss Curve")
    plt.show()

    plt.figure()
    plt.plot(history["train_accs"], label="Train Acc")
    plt.plot(history["val_accs"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy Curve")
    plt.show()

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# **Experiment Function**

# %%
def run_experiment(lr, batch_size, dropout, epochs, device):
    train_loader, val_loader, _ = make_loaders(batch_size)

    model = SimpleCNN(dropout=dropout).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    history = fit(model, train_loader, val_loader, criterion, optimizer, device, epochs)

    return {
        "lr": lr,
        "batch_size": batch_size,
        "dropout": dropout,
        "best_val_acc": history["best_val_acc"],
        "best_state": history["best_state"]
    }

# %% [markdown]
# **Tuning Grid Loop & Results Table**

# %%
lrs = [1e-2, 1e-3, 1e-4]
batch_sizes = [32, 64]
dropouts = [0.2, 0.5]
EPOCHS_TUNE = 10

results = []
best_run = None

for lr in lrs:
    for bs in batch_sizes:
        for do in dropouts:
            out = run_experiment(lr, bs, do, EPOCHS_TUNE, device)
            results.append({
                "lr": out["lr"],
                "batch_size": out["batch_size"],
                "dropout": out["dropout"],
                "best_val_acc": out["best_val_acc"]
            })

            if (best_run is None) or (out["best_val_acc"] > best_run["best_val_acc"]):
                best_run = out

df_results = pd.DataFrame(results).sort_values(by="best_val_acc", ascending=False)
df_results
# Out:
# Epoch 1/10 | Train Loss: 2.1782, Train Acc: 0.2153 | Val Loss: 1.7999, Val Acc: 0.2500
# Epoch 2/10 | Train Loss: 1.8822, Train Acc: 0.2508 | Val Loss: 1.6970, Val Acc: 0.3250
# Epoch 3/10 | Train Loss: 1.7985, Train Acc: 0.2959 | Val Loss: 1.6403, Val Acc: 0.3254
# Epoch 4/10 | Train Loss: 1.7417, Train Acc: 0.3221 | Val Loss: 1.5109, Val Acc: 0.4496
# Epoch 5/10 | Train Loss: 1.6378, Train Acc: 0.3839 | Val Loss: 1.4451, Val Acc: 0.4644
# Epoch 6/10 | Train Loss: 1.5708, Train Acc: 0.4117 | Val Loss: 1.3252, Val Acc: 0.5292
# Epoch 7/10 | Train Loss: 1.5132, Train Acc: 0.4433 | Val Loss: 1.3502, Val Acc: 0.5198
# Epoch 8/10 | Train Loss: 1.4701, Train Acc: 0.4621 | Val Loss: 1.2128, Val Acc: 0.5704
# Epoch 9/10 | Train Loss: 1.4370, Train Acc: 0.4762 | Val Loss: 1.2015, Val Acc: 0.5662
# Epoch 10/10 | Train Loss: 1.4153, Train Acc: 0.4817 | Val Loss: 1.2090, Val Acc: 0.5688
# Epoch 1/10 | Train Loss: 2.3888, Train Acc: 0.1053 | Val Loss: 2.3037, Val Acc: 0.1000
# Epoch 2/10 | Train Loss: 2.3041, Train Acc: 0.1008 | Val Loss: 2.3044, Val Acc: 0.1002
# Epoch 3/10 | Train Loss: 2.3041, Train Acc: 0.0972 | Val Loss: 2.3045, Val Acc: 0.1014
# Epoch 4/10 | Train Loss: 2.3042, Train Acc: 0.0984 | Val Loss: 2.3041, Val Acc: 0.1002
# Epoch 5/10 | Train Loss: 2.3039, Train Acc: 0.0981 | Val Loss: 2.3029, Val Acc: 0.1000
# Epoch 6/10 | Train Loss: 2.3039, Train Acc: 0.0987 | Val Loss: 2.3055, Val Acc: 0.1024
# Epoch 7/10 | Train Loss: 2.3042, Train Acc: 0.0984 | Val Loss: 2.3044, Val Acc: 0.1024
# Epoch 8/10 | Train Loss: 2.3039, Train Acc: 0.0996 | Val Loss: 2.3036, Val Acc: 0.0976
# Epoch 9/10 | Train Loss: 2.3040, Train Acc: 0.0973 | Val Loss: 2.3037, Val Acc: 0.1028
# Epoch 10/10 | Train Loss: 2.3040, Train Acc: 0.0992 | Val Loss: 2.3044, Val Acc: 0.1028
# Epoch 1/10 | Train Loss: 2.2387, Train Acc: 0.2386 | Val Loss: 1.7393, Val Acc: 0.3390
# Epoch 2/10 | Train Loss: 1.8215, Train Acc: 0.2979 | Val Loss: 1.5852, Val Acc: 0.4008
# Epoch 3/10 | Train Loss: 1.7374, Train Acc: 0.3374 | Val Loss: 1.5645, Val Acc: 0.4412
# Epoch 4/10 | Train Loss: 1.6607, Train Acc: 0.3793 | Val Loss: 1.4143, Val Acc: 0.4976
# Epoch 5/10 | Train Loss: 1.5972, Train Acc: 0.4081 | Val Loss: 1.4280, Val Acc: 0.5042
# Epoch 6/10 | Train Loss: 1.5428, Train Acc: 0.4332 | Val Loss: 1.2761, Val Acc: 0.5498
# Epoch 7/10 | Train Loss: 1.4877, Train Acc: 0.4595 | Val Loss: 1.2377, Val Acc: 0.5558
# Epoch 8/10 | Train Loss: 1.4538, Train Acc: 0.4731 | Val Loss: 1.2309, Val Acc: 0.5730
# Epoch 9/10 | Train Loss: 1.4178, Train Acc: 0.4899 | Val Loss: 1.1412, Val Acc: 0.5934
# Epoch 10/10 | Train Loss: 1.3586, Train Acc: 0.5092 | Val Loss: 1.1304, Val Acc: 0.5972
# Epoch 1/10 | Train Loss: 2.3182, Train Acc: 0.1549 | Val Loss: 1.9662, Val Acc: 0.2396
# Epoch 2/10 | Train Loss: 2.0703, Train Acc: 0.1802 | Val Loss: 1.8612, Val Acc: 0.2552
# Epoch 3/10 | Train Loss: 2.0121, Train Acc: 0.1948 | Val Loss: 1.7740, Val Acc: 0.2530
# Epoch 4/10 | Train Loss: 1.9962, Train Acc: 0.2026 | Val Loss: 1.7494, Val Acc: 0.2948
# Epoch 5/10 | Train Loss: 1.9259, Train Acc: 0.2350 | Val Loss: 1.6466, Val Acc: 0.3798
# Epoch 6/10 | Train Loss: 1.8501, Train Acc: 0.2756 | Val Loss: 1.5820, Val Acc: 0.3656
# Epoch 7/10 | Train Loss: 1.7874, Train Acc: 0.3024 | Val Loss: 1.5407, Val Acc: 0.3990
# Epoch 8/10 | Train Loss: 1.7433, Train Acc: 0.3189 | Val Loss: 1.4740, Val Acc: 0.4260
# Epoch 9/10 | Train Loss: 1.7269, Train Acc: 0.3246 | Val Loss: 1.5248, Val Acc: 0.3780
# Epoch 10/10 | Train Loss: 1.7013, Train Acc: 0.3393 | Val Loss: 1.4011, Val Acc: 0.4632
# Epoch 1/10 | Train Loss: 1.5950, Train Acc: 0.4131 | Val Loss: 1.2284, Val Acc: 0.5494
# Epoch 2/10 | Train Loss: 1.3125, Train Acc: 0.5269 | Val Loss: 1.0761, Val Acc: 0.6142
# Epoch 3/10 | Train Loss: 1.2061, Train Acc: 0.5675 | Val Loss: 0.9988, Val Acc: 0.6412
# Epoch 4/10 | Train Loss: 1.1438, Train Acc: 0.5934 | Val Loss: 0.9252, Val Acc: 0.6764
# Epoch 5/10 | Train Loss: 1.0915, Train Acc: 0.6112 | Val Loss: 0.8984, Val Acc: 0.6772
# Epoch 6/10 | Train Loss: 1.0504, Train Acc: 0.6281 | Val Loss: 0.8852, Val Acc: 0.6866
# Epoch 7/10 | Train Loss: 1.0159, Train Acc: 0.6426 | Val Loss: 0.8704, Val Acc: 0.6926
# Epoch 8/10 | Train Loss: 0.9853, Train Acc: 0.6538 | Val Loss: 0.8551, Val Acc: 0.6946
# Epoch 9/10 | Train Loss: 0.9553, Train Acc: 0.6662 | Val Loss: 0.7926, Val Acc: 0.7208
# Epoch 10/10 | Train Loss: 0.9329, Train Acc: 0.6722 | Val Loss: 0.7732, Val Acc: 0.7238
# Epoch 1/10 | Train Loss: 1.7576, Train Acc: 0.3388 | Val Loss: 1.4649, Val Acc: 0.4566
# Epoch 2/10 | Train Loss: 1.5509, Train Acc: 0.4241 | Val Loss: 1.2436, Val Acc: 0.5548
# Epoch 3/10 | Train Loss: 1.4639, Train Acc: 0.4606 | Val Loss: 1.1880, Val Acc: 0.5736
# Epoch 4/10 | Train Loss: 1.3949, Train Acc: 0.4898 | Val Loss: 1.0931, Val Acc: 0.6100
# Epoch 5/10 | Train Loss: 1.3532, Train Acc: 0.5066 | Val Loss: 1.0514, Val Acc: 0.6316
# Epoch 6/10 | Train Loss: 1.3145, Train Acc: 0.5264 | Val Loss: 1.0070, Val Acc: 0.6486
# Epoch 7/10 | Train Loss: 1.2807, Train Acc: 0.5354 | Val Loss: 0.9755, Val Acc: 0.6500
# Epoch 8/10 | Train Loss: 1.2520, Train Acc: 0.5497 | Val Loss: 0.9621, Val Acc: 0.6522
# Epoch 9/10 | Train Loss: 1.2267, Train Acc: 0.5592 | Val Loss: 0.9261, Val Acc: 0.6780
# Epoch 10/10 | Train Loss: 1.1986, Train Acc: 0.5689 | Val Loss: 0.9144, Val Acc: 0.6664
# Epoch 1/10 | Train Loss: 1.5513, Train Acc: 0.4318 | Val Loss: 1.2333, Val Acc: 0.5532
# Epoch 2/10 | Train Loss: 1.2787, Train Acc: 0.5377 | Val Loss: 1.0451, Val Acc: 0.6266
# Epoch 3/10 | Train Loss: 1.1772, Train Acc: 0.5780 | Val Loss: 0.9850, Val Acc: 0.6474
# Epoch 4/10 | Train Loss: 1.1173, Train Acc: 0.6014 | Val Loss: 0.9709, Val Acc: 0.6510
# Epoch 5/10 | Train Loss: 1.0644, Train Acc: 0.6228 | Val Loss: 0.9175, Val Acc: 0.6728
# Epoch 6/10 | Train Loss: 1.0275, Train Acc: 0.6371 | Val Loss: 0.8668, Val Acc: 0.6904
# Epoch 7/10 | Train Loss: 0.9990, Train Acc: 0.6475 | Val Loss: 0.8643, Val Acc: 0.6926
# Epoch 8/10 | Train Loss: 0.9660, Train Acc: 0.6572 | Val Loss: 0.8022, Val Acc: 0.7144
# Epoch 9/10 | Train Loss: 0.9413, Train Acc: 0.6683 | Val Loss: 0.8237, Val Acc: 0.7064
# Epoch 10/10 | Train Loss: 0.9178, Train Acc: 0.6786 | Val Loss: 0.8429, Val Acc: 0.7070
# Epoch 1/10 | Train Loss: 1.7679, Train Acc: 0.3382 | Val Loss: 1.3935, Val Acc: 0.4940
# Epoch 2/10 | Train Loss: 1.5427, Train Acc: 0.4264 | Val Loss: 1.2558, Val Acc: 0.5666
# Epoch 3/10 | Train Loss: 1.4358, Train Acc: 0.4714 | Val Loss: 1.1143, Val Acc: 0.6048
# Epoch 4/10 | Train Loss: 1.3701, Train Acc: 0.5034 | Val Loss: 1.0862, Val Acc: 0.6072
# Epoch 5/10 | Train Loss: 1.3268, Train Acc: 0.5194 | Val Loss: 1.0445, Val Acc: 0.6350
# Epoch 6/10 | Train Loss: 1.2898, Train Acc: 0.5351 | Val Loss: 0.9954, Val Acc: 0.6390
# Epoch 7/10 | Train Loss: 1.2570, Train Acc: 0.5477 | Val Loss: 0.9767, Val Acc: 0.6606
# Epoch 8/10 | Train Loss: 1.2258, Train Acc: 0.5580 | Val Loss: 0.9530, Val Acc: 0.6596
# Epoch 9/10 | Train Loss: 1.2035, Train Acc: 0.5679 | Val Loss: 0.9011, Val Acc: 0.6808
# Epoch 10/10 | Train Loss: 1.1848, Train Acc: 0.5788 | Val Loss: 0.9683, Val Acc: 0.6618
# Epoch 1/10 | Train Loss: 1.5880, Train Acc: 0.4260 | Val Loss: 1.2457, Val Acc: 0.5574
# Epoch 2/10 | Train Loss: 1.3002, Train Acc: 0.5316 | Val Loss: 1.1070, Val Acc: 0.6088
# Epoch 3/10 | Train Loss: 1.2018, Train Acc: 0.5685 | Val Loss: 1.0239, Val Acc: 0.6444
# Epoch 4/10 | Train Loss: 1.1366, Train Acc: 0.5946 | Val Loss: 0.9654, Val Acc: 0.6580
# Epoch 5/10 | Train Loss: 1.0970, Train Acc: 0.6080 | Val Loss: 0.9365, Val Acc: 0.6674
# Epoch 6/10 | Train Loss: 1.0563, Train Acc: 0.6266 | Val Loss: 0.9117, Val Acc: 0.6746
# Epoch 7/10 | Train Loss: 1.0218, Train Acc: 0.6378 | Val Loss: 0.8892, Val Acc: 0.6830
# Epoch 8/10 | Train Loss: 0.9965, Train Acc: 0.6488 | Val Loss: 0.8622, Val Acc: 0.6934
# Epoch 9/10 | Train Loss: 0.9702, Train Acc: 0.6565 | Val Loss: 0.8347, Val Acc: 0.7036
# Epoch 10/10 | Train Loss: 0.9498, Train Acc: 0.6639 | Val Loss: 0.8197, Val Acc: 0.7068
# Epoch 1/10 | Train Loss: 1.7154, Train Acc: 0.3711 | Val Loss: 1.3502, Val Acc: 0.5154
# Epoch 2/10 | Train Loss: 1.4571, Train Acc: 0.4691 | Val Loss: 1.2152, Val Acc: 0.5720
# Epoch 3/10 | Train Loss: 1.3465, Train Acc: 0.5147 | Val Loss: 1.1206, Val Acc: 0.6168
# Epoch 4/10 | Train Loss: 1.2763, Train Acc: 0.5410 | Val Loss: 1.0727, Val Acc: 0.6264
# Epoch 5/10 | Train Loss: 1.2297, Train Acc: 0.5611 | Val Loss: 1.0093, Val Acc: 0.6504
# Epoch 6/10 | Train Loss: 1.1916, Train Acc: 0.5745 | Val Loss: 0.9788, Val Acc: 0.6598
# Epoch 7/10 | Train Loss: 1.1653, Train Acc: 0.5844 | Val Loss: 0.9615, Val Acc: 0.6604
# Epoch 8/10 | Train Loss: 1.1346, Train Acc: 0.5961 | Val Loss: 0.9356, Val Acc: 0.6792
# Epoch 9/10 | Train Loss: 1.1145, Train Acc: 0.6032 | Val Loss: 0.9274, Val Acc: 0.6738
# Epoch 10/10 | Train Loss: 1.0994, Train Acc: 0.6076 | Val Loss: 0.8985, Val Acc: 0.6810
# Epoch 1/10 | Train Loss: 1.6517, Train Acc: 0.3992 | Val Loss: 1.3275, Val Acc: 0.5248
# Epoch 2/10 | Train Loss: 1.3597, Train Acc: 0.5117 | Val Loss: 1.1553, Val Acc: 0.5902
# Epoch 3/10 | Train Loss: 1.2414, Train Acc: 0.5581 | Val Loss: 1.0669, Val Acc: 0.6212
# Epoch 4/10 | Train Loss: 1.1694, Train Acc: 0.5837 | Val Loss: 1.0069, Val Acc: 0.6402
# Epoch 5/10 | Train Loss: 1.1129, Train Acc: 0.6054 | Val Loss: 0.9824, Val Acc: 0.6492
# Epoch 6/10 | Train Loss: 1.0793, Train Acc: 0.6186 | Val Loss: 0.9284, Val Acc: 0.6802
# Epoch 7/10 | Train Loss: 1.0463, Train Acc: 0.6288 | Val Loss: 0.9028, Val Acc: 0.6884
# Epoch 8/10 | Train Loss: 1.0129, Train Acc: 0.6422 | Val Loss: 0.8924, Val Acc: 0.6898
# Epoch 9/10 | Train Loss: 0.9935, Train Acc: 0.6520 | Val Loss: 0.8769, Val Acc: 0.6956
# Epoch 10/10 | Train Loss: 0.9675, Train Acc: 0.6590 | Val Loss: 0.8511, Val Acc: 0.7074
# Epoch 1/10 | Train Loss: 1.7326, Train Acc: 0.3671 | Val Loss: 1.4074, Val Acc: 0.4898
# Epoch 2/10 | Train Loss: 1.4648, Train Acc: 0.4693 | Val Loss: 1.2235, Val Acc: 0.5620
# Epoch 3/10 | Train Loss: 1.3565, Train Acc: 0.5115 | Val Loss: 1.1477, Val Acc: 0.5928
# Epoch 4/10 | Train Loss: 1.2888, Train Acc: 0.5360 | Val Loss: 1.0861, Val Acc: 0.6154
# Epoch 5/10 | Train Loss: 1.2396, Train Acc: 0.5575 | Val Loss: 1.0332, Val Acc: 0.6284
# Epoch 6/10 | Train Loss: 1.2014, Train Acc: 0.5723 | Val Loss: 1.0010, Val Acc: 0.6450
# Epoch 7/10 | Train Loss: 1.1678, Train Acc: 0.5848 | Val Loss: 0.9764, Val Acc: 0.6536
# Epoch 8/10 | Train Loss: 1.1395, Train Acc: 0.5953 | Val Loss: 0.9479, Val Acc: 0.6616
# Epoch 9/10 | Train Loss: 1.1207, Train Acc: 0.6041 | Val Loss: 0.9254, Val Acc: 0.6724
# Epoch 10/10 | Train Loss: 1.0999, Train Acc: 0.6093 | Val Loss: 0.9186, Val Acc: 0.6692
#         lr  batch_size  dropout  best_val_acc
# 4   0.0010          32      0.2        0.7238
# 6   0.0010          64      0.2        0.7144
# 10  0.0001          64      0.2        0.7074
# 8   0.0001          32      0.2        0.7068
# 9   0.0001          32      0.5        0.6810
# 7   0.0010          64      0.5        0.6808
# 5   0.0010          32      0.5        0.6780
# 11  0.0001          64      0.5        0.6724
# 2   0.0100          64      0.2        0.5972
# 0   0.0100          32      0.2        0.5704
# 3   0.0100          64      0.5        0.4632
# 1   0.0100          32      0.5        0.1028

# %% [markdown]
# **Save tuning CSV**

# %%
df_results.to_csv(f"{RESULTS_DIR}/tuning_results.csv", index=False)
print("Saved:", f"{RESULTS_DIR}/tuning_results.csv")
# Out:
# Saved: results/tuning_results.csv

# %% [markdown]
# **Save best_config.json**

# %%
best_row = df_results.iloc[0].to_dict()

best_config = {
    "lr": float(best_row["lr"]),
    "batch_size": int(best_row["batch_size"]),
    "dropout": float(best_row["dropout"]),
    "best_val_acc": float(best_row["best_val_acc"])
}

with open(f"{RESULTS_DIR}/best_config.json", "w") as f:
    json.dump(best_config, f, indent=2)

print("Saved:", f"{RESULTS_DIR}/best_config.json")
best_config
# Out:
# Saved: results/best_config.json
# {'lr': 0.001, 'batch_size': 32, 'dropout': 0.2, 'best_val_acc': 0.7238}

# %% [markdown]
# ### Final Training

# %%
BEST_LR = float(best_run["lr"])
BEST_BS = int(best_run["batch_size"])
BEST_DO = float(best_run["dropout"])

print("Best config:", {"lr": BEST_LR, "batch_size": BEST_BS, "dropout": BEST_DO})

train_loader, val_loader, test_loader = make_loaders(BEST_BS)

model = SimpleCNN(dropout=BEST_DO).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=BEST_LR)

EPOCHS_FINAL = 30
history = fit(model, train_loader, val_loader, criterion, optimizer, device, EPOCHS_FINAL)

model.load_state_dict(history["best_state"])
model.to(device)

plot_curves(history)
print("Best Val Acc:", history["best_val_acc"])


plt.savefig(f"{RESULTS_DIR}/training_curves.png", dpi=200, bbox_inches="tight")
plt.show()

print("Saved:", f"{RESULTS_DIR}/training_curves.png")
# Out:
# Best config: {'lr': 0.001, 'batch_size': 32, 'dropout': 0.2}
# Epoch 1/30 | Train Loss: 1.6002, Train Acc: 0.4091 | Val Loss: 1.3164, Val Acc: 0.5184
# Epoch 2/30 | Train Loss: 1.3449, Train Acc: 0.5086 | Val Loss: 1.0823, Val Acc: 0.6074
# Epoch 3/30 | Train Loss: 1.2287, Train Acc: 0.5602 | Val Loss: 0.9942, Val Acc: 0.6454
# Epoch 4/30 | Train Loss: 1.1620, Train Acc: 0.5847 | Val Loss: 0.9767, Val Acc: 0.6600
# Epoch 5/30 | Train Loss: 1.1072, Train Acc: 0.6051 | Val Loss: 0.9064, Val Acc: 0.6846
# Epoch 6/30 | Train Loss: 1.0666, Train Acc: 0.6215 | Val Loss: 0.8544, Val Acc: 0.6978
# Epoch 7/30 | Train Loss: 1.0312, Train Acc: 0.6349 | Val Loss: 0.8492, Val Acc: 0.7028
# Epoch 8/30 | Train Loss: 1.0022, Train Acc: 0.6462 | Val Loss: 0.8182, Val Acc: 0.7142
# Epoch 9/30 | Train Loss: 0.9753, Train Acc: 0.6579 | Val Loss: 0.8033, Val Acc: 0.7208
# Epoch 10/30 | Train Loss: 0.9515, Train Acc: 0.6654 | Val Loss: 0.7739, Val Acc: 0.7258
# Epoch 11/30 | Train Loss: 0.9297, Train Acc: 0.6741 | Val Loss: 0.7750, Val Acc: 0.7266
# Epoch 12/30 | Train Loss: 0.9140, Train Acc: 0.6793 | Val Loss: 0.7455, Val Acc: 0.7394
# Epoch 13/30 | Train Loss: 0.9034, Train Acc: 0.6810 | Val Loss: 0.7347, Val Acc: 0.7424
# Epoch 14/30 | Train Loss: 0.8870, Train Acc: 0.6907 | Val Loss: 0.7409, Val Acc: 0.7408
# Epoch 15/30 | Train Loss: 0.8781, Train Acc: 0.6920 | Val Loss: 0.7397, Val Acc: 0.7350
# Epoch 16/30 | Train Loss: 0.8627, Train Acc: 0.6996 | Val Loss: 0.7147, Val Acc: 0.7506
# Epoch 17/30 | Train Loss: 0.8512, Train Acc: 0.7027 | Val Loss: 0.7246, Val Acc: 0.7510
# Epoch 18/30 | Train Loss: 0.8424, Train Acc: 0.7071 | Val Loss: 0.6978, Val Acc: 0.7528
# Epoch 19/30 | Train Loss: 0.8283, Train Acc: 0.7136 | Val Loss: 0.7014, Val Acc: 0.7578
# Epoch 20/30 | Train Loss: 0.8289, Train Acc: 0.7122 | Val Loss: 0.7166, Val Acc: 0.7516
# Epoch 21/30 | Train Loss: 0.8143, Train Acc: 0.7152 | Val Loss: 0.7035, Val Acc: 0.7560
# Epoch 22/30 | Train Loss: 0.8085, Train Acc: 0.7171 | Val Loss: 0.6726, Val Acc: 0.7606
# Epoch 23/30 | Train Loss: 0.8007, Train Acc: 0.7234 | Val Loss: 0.6603, Val Acc: 0.7668
# Epoch 24/30 | Train Loss: 0.7925, Train Acc: 0.7229 | Val Loss: 0.6588, Val Acc: 0.7658
# Epoch 25/30 | Train Loss: 0.7883, Train Acc: 0.7262 | Val Loss: 0.6715, Val Acc: 0.7666
# Epoch 26/30 | Train Loss: 0.7838, Train Acc: 0.7272 | Val Loss: 0.6569, Val Acc: 0.7718
# Epoch 27/30 | Train Loss: 0.7798, Train Acc: 0.7282 | Val Loss: 0.6650, Val Acc: 0.7668
# Epoch 28/30 | Train Loss: 0.7694, Train Acc: 0.7309 | Val Loss: 0.6296, Val Acc: 0.7820
# Epoch 29/30 | Train Loss: 0.7620, Train Acc: 0.7355 | Val Loss: 0.6419, Val Acc: 0.7740
# Epoch 30/30 | Train Loss: 0.7611, Train Acc: 0.7357 | Val Loss: 0.6636, Val Acc: 0.7668
# Best Val Acc: 0.782
# Saved: results/training_curves.png

# %% [markdown]
# ### Evaluation

# %%
test_loss, test_acc = evaluate(model, test_loader, criterion, device)
print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 0.6389 | Test Acc: 0.7786

# %%
@torch.no_grad()
def collect_predictions(model, loader, device):
    model.eval()
    all_preds, all_labels = [], []

    for images, labels in loader:
        images = images.to(device)
        outputs = model(images)
        preds = outputs.argmax(dim=1).cpu()

        all_preds.append(preds)
        all_labels.append(labels)

    return torch.cat(all_preds), torch.cat(all_labels)

all_preds, all_labels = collect_predictions(model, test_loader, device)

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(7, 6))
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.colorbar()
plt.tight_layout()

plt.savefig(f"{RESULTS_DIR}/confusion_matrix.png", dpi=200, bbox_inches="tight")
plt.show()

print("Saved:", f"{RESULTS_DIR}/confusion_matrix.png")

print(classification_report(all_labels, all_preds, target_names=class_names))
# Out:
# Saved: results/confusion_matrix.png
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.80      0.80      1000
#   automobile       0.90      0.90      0.90      1000
#         bird       0.73      0.63      0.67      1000
#          cat       0.64      0.55      0.59      1000
#         deer       0.79      0.70      0.75      1000
#          dog       0.65      0.74      0.69      1000
#         frog       0.80      0.85      0.82      1000
#        horse       0.75      0.86      0.80      1000
#         ship       0.88      0.88      0.88      1000
#        truck       0.84      0.87      0.85      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.78     10000
# weighted avg       0.78      0.78      0.78     10000

# %% [markdown]
# ### Save Model and Weights

# %%
torch.save(model.state_dict(), f"{MODELS_DIR}/cifar10_cnn_best.pth")
print("Saved:", f"{MODELS_DIR}/cifar10_cnn_best.pth")
# Out:
# Saved: models/cifar10_cnn_best.pth
